# %%
# data analysis
import pandas as pd

from sklearn import preprocessing

# data segmentation: 2 second, 80% overlapping, 55Hz
def data_processing(filename):
    # read data
    cleaned_data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\%s_dataset.csv' %filename)
#     cleaned_data = cleaned_data.astype(float)
    
#     cleaned_data = pd.DataFrame(preprocessing.normalize(cleaned_data.drop(['activity', 'voltage', 'current', 'power', 'energy'], 
#                                                                       axis=1)),
#                                                    columns=['AcX 1', 'AcY 1', 'AcZ 1', 'GyX 1', 'GyY 1', 'GyZ 1', 
#                                                             'AcX 2', 'AcY 2', 'AcZ 2', 'GyX 2', 'GyY 2', 'GyZ 2',
#                                                             'AcX 3', 'AcY 3', 'AcZ 3', 'GyX 3', 'GyY 3', 'GyZ 3'])
    cleaned_data = cleaned_data.drop(['activity', 'voltage', 'current', 'power', 'energy'],  axis=1)
    mean_data = pd.DataFrame()
#     max_data = pd.DataFrame()
    iqr_data = pd.DataFrame()
    mad_data = pd.DataFrame()
#     median_data = pd.DataFrame()
    std_data = pd.DataFrame()
    
    i = 0
    row_count = len(cleaned_data.index)

    # segmentation at 80% @ 55Hz 2s
    while i + 110 <=  row_count:
        a = cleaned_data[i:i+110:].copy()

        a.loc['mean'] = a.mean()
#         a.loc['max'] = a.max()
        a.loc['iqr'] = a.quantile(0.75) - a.quantile(0.25)
        a.loc['mad'] = a.mad()
#         a.loc['median'] = a.median()
        a.loc['std'] = a.std()
        
        mean_data = mean_data.append(a.loc['mean'], ignore_index=True)
#         max_data = max_data.append(a.loc['max'], ignore_index=True)
        iqr_data = iqr_data.append(a.loc['iqr'], ignore_index=True)
        mad_data = mad_data.append(a.loc['mad'], ignore_index=True)
#         median_data = median_data.append(a.loc['median'], ignore_index=True)
        std_data = mad_data.append(a.loc['std'], ignore_index=True)
        
        i += 11
        
    # rearrangement of columns
    mean_data = mean_data.rename(index=str, columns={'AcX 1': 'mean_AcX 1', 'AcY 1': 'mean_AcY 1', 'AcZ 1': 'mean_AcZ 1', 
                                                      'GyX 1': 'mean_GyX 1', 'GyY 1': 'mean_GyY 1', 'GyZ 1': 'mean_GyZ 1',
                                                      'AcX 2': 'mean_AcX 2', 'AcY 2': 'mean_AcY 2', 'AcZ 2': 'mean_AcZ 2', 
                                                      'GyX 2': 'mean_GyX 2', 'GyY 2': 'mean_GyY 2', 'GyZ 2': 'mean_GyZ 2',
                                                      'AcX 3': 'mean_AcX 3', 'AcY 3': 'mean_AcY 3', 'AcZ 3': 'mean_AcZ 3', 
                                                      'GyX 3': 'mean_GyX 3', 'GyY 3': 'mean_GyY 3', 'GyZ 3': 'mean_GyZ 3',})
  
#     max_data = max_data.rename(index=str, columns=  {'AcX 1': 'max_AcX 1', 'AcY 1': 'max_AcY 1', 'AcZ 1': 'max_AcZ 1', 
#                                                      'GyX 1': 'max_GyX 1', 'GyY 1': 'max_GyY 1', 'GyZ 1': 'max_GyZ 1',
#                                                      'AcX 2': 'max_AcX 2', 'AcY 2': 'max_AcY 2', 'AcZ 2': 'max_AcZ 2', 
#                                                      'GyX 2': 'max_GyX 2', 'GyY 2': 'max_GyY 2', 'GyZ 2': 'max_GyZ 2',
#                                                      'AcX 3': 'max_AcX 3', 'AcY 3': 'max_AcY 3', 'AcZ 3': 'max_AcZ 3', 
#                                                      'GyX 3': 'max_GyX 3', 'GyY 3': 'max_GyY 3', 'GyZ 3': 'max_GyZ 3',}) 
    
    iqr_data = iqr_data.rename(index=str, columns=  {'AcX 1': 'iqr_AcX 1', 'AcY 1': 'iqr_AcY 1', 'AcZ 1': 'iqr_AcZ 1', 
                                                     'GyX 1': 'iqr_GyX 1', 'GyY 1': 'iqr_GyY 1', 'GyZ 1': 'iqr_GyZ 1',
                                                     'AcX 2': 'iqr_AcX 2', 'AcY 2': 'iqr_AcY 2', 'AcZ 2': 'iqr_AcZ 2', 
                                                     'GyX 2': 'iqr_GyX 2', 'GyY 2': 'iqr_GyY 2', 'GyZ 2': 'iqr_GyZ 2',
                                                     'AcX 3': 'iqr_AcX 3', 'AcY 3': 'iqr_AcY 3', 'AcZ 3': 'iqr_AcZ 3', 
                                                     'GyX 3': 'iqr_GyX 3', 'GyY 3': 'iqr_GyY 3', 'GyZ 3': 'iqr_GyZ 3',}) 
    
    mad_data = mad_data.rename(index=str, columns=  {'AcX 1': 'mad_AcX 1', 'AcY 1': 'mad_AcY 1', 'AcZ 1': 'mad_AcZ 1', 
                                                     'GyX 1': 'mad_GyX 1', 'GyY 1': 'mad_GyY 1', 'GyZ 1': 'mad_GyZ 1',
                                                     'AcX 2': 'mad_AcX 2', 'AcY 2': 'mad_AcY 2', 'AcZ 2': 'mad_AcZ 2', 
                                                     'GyX 2': 'mad_GyX 2', 'GyY 2': 'mad_GyY 2', 'GyZ 2': 'mad_GyZ 2',
                                                     'AcX 3': 'mad_AcX 3', 'AcY 3': 'mad_AcY 3', 'AcZ 3': 'mad_AcZ 3', 
                                                     'GyX 3': 'mad_GyX 3', 'GyY 3': 'mad_GyY 3', 'GyZ 3': 'mad_GyZ 3',}) 
    
    std_data = std_data.rename(index=str, columns=  {'AcX 1': 'std_AcX 1', 'AcY 1': 'std_AcY 1', 'AcZ 1': 'std_AcZ 1', 
                                                     'GyX 1': 'std_GyX 1', 'GyY 1': 'std_GyY 1', 'GyZ 1': 'std_GyZ 1',
                                                     'AcX 2': 'std_AcX 2', 'AcY 2': 'std_AcY 2', 'AcZ 2': 'std_AcZ 2', 
                                                     'GyX 2': 'std_GyX 2', 'GyY 2': 'std_GyY 2', 'GyZ 2': 'std_GyZ 2',
                                                     'AcX 3': 'std_AcX 3', 'AcY 3': 'std_AcY 3', 'AcZ 3': 'std_AcZ 3', 
                                                     'GyX 3': 'std_GyX 3', 'GyY 3': 'std_GyY 3', 'GyZ 3': 'std_GyZ 3',}) 
    
#     median_data = median_data.rename(index=str, columns=  {'AcX 1': 'median_AcX 1', 'AcY 1': 'median_AcY 1', 'AcZ 1': 'median_AcZ 1', 
#                                                      'GyX 1': 'median_GyX 1', 'GyY 1': 'median_GyY 1', 'GyZ 1': 'median_GyZ 1',
#                                                      'AcX 2': 'median_AcX 2', 'AcY 2': 'median_AcY 2', 'AcZ 2': 'median_AcZ 2', 
#                                                      'GyX 2': 'median_GyX 2', 'GyY 2': 'median_GyY 2', 'GyZ 2': 'median_GyZ 2',
#                                                      'AcX 3': 'median_AcX 3', 'AcY 3': 'median_AcY 3', 'AcZ 3': 'median_AcZ 3', 
#                                                      'GyX 3': 'median_GyX 3', 'GyY 3': 'median_GyY 3', 'GyZ 3': 'median_GyZ 3',}) 
    
    
    # combine features extracted into 1 
    extracted_data = mean_data.join(std_data).join(iqr_data).join(mad_data)
    
    mapping = {'rest' : 0, 'chicken' : 1, 'number7' : 2, 'sidestep' : 3, 'turnclap' : 4, 'wipers' : 5,
               'numbersix' : 6, 'salute' : 7, 'mermaid' : 8, 'swing' : 9, 'cowboy' : 10, 'finisher' : 11}
    extracted_data['activity'] = filename
    extracted_data = extracted_data.replace({'activity': mapping})
    
    extracted_data.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\%s_extracted_dataset.csv' %filename,index=False)

# %%
import pandas as pd
import winsound

data_processing("chicken")
print('chicken 1/12 done')
data_processing("number7")
print('number7 2/12 done')
data_processing("sidestep")
print('sidestep 3/12 done')
data_processing("turnclap")
print('turnclap 4/12 done')
data_processing("wipers")
print('wipers 5/12 done')
data_processing("numbersix")
print('numbersix 6/12 done')
data_processing("salute")
print('salute 7/12 done')
data_processing("mermaid")
print('mermaid 8/12 done')
data_processing("swing")
print('swing 9/12 done')
data_processing("cowboy")
print('cowboy 10/12 done')
data_processing("finisher")
print('finisher 11/12 done')
data_processing("rest")
print('rest 12/12 done')

chicken = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\chicken_extracted_dataset.csv')
number7 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\number7_extracted_dataset.csv')
sidestep = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\sidestep_extracted_dataset.csv')
turnclap = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\turnclap_extracted_dataset.csv')
wiper = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\wipers_extracted_dataset.csv')
number6 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\numbersix_extracted_dataset.csv')
salute = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\salute_extracted_dataset.csv')
mermaid = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\mermaid_extracted_dataset.csv')
swing = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\swing_extracted_dataset.csv')
cowboy = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\cowboy_extracted_dataset.csv')
finisher = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\finisher_extracted_dataset.csv')
rest = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\rest_extracted_dataset.csv')

frames_result = [chicken, number7, sidestep, turnclap, wiper, number6, salute, mermaid, swing, cowboy, finisher, rest]

result = pd.concat(frames_result)
# result = result.drop(['voltage', 'current', 'power', 'energy'], axis = 1).copy()
result.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\extracted_dataset.csv', index=False)
print("all done")
winsound.Beep(500, 800)
# Out:
# chicken 1/12 done
# number7 2/12 done
# sidestep 3/12 done
# turnclap 4/12 done
# wipers 5/12 done
# numbersix 6/12 done
# salute 7/12 done
# mermaid 8/12 done
# swing 9/12 done
# cowboy 10/12 done
# finisher 11/12 done
# rest 12/12 done
# all done
