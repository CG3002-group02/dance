# %%
# data analysis
import pandas as pd

# scale the data points
from sklearn import preprocessing

import datetime

def data_processing(filename):
    # read data
#     data = pd.read_csv('/home/pi/3002/readings.csv')
    start_time = datetime.datetime.now()
    data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\test data\%s_dataset.csv' %filename)
    data = data.head(110)
    
    cleaned_data = data.drop(['voltage','current','power','energy', 'activity'],axis =1).copy() #delete column
#     cleaned_data = cleaned_data.astype(float)
#     cleaned_data = pd.DataFrame(preprocessing.scale(cleaned_data),
#                                                    columns=['AcX 1', 'AcY 1', 'AcZ 1', 'GyX 1', 'GyY 1', 'GyZ 1',                                                           
#                                                             'AcX 2', 'AcY 2', 'AcZ 2', 'GyX 2', 'GyY 2', 'GyZ 2',
#                                                             'AcX 3', 'AcY 3', 'AcZ 3', 'GyX 3', 'GyY 3', 'GyZ 3'])
    
    end_time = datetime.datetime.now()
    time_taken = end_time - start_time
    print("time taken for reading = ", time_taken)
    mean_data = pd.DataFrame() 
    max_data = pd.DataFrame()
    iqr_data = pd.DataFrame()
    mad_data = pd.DataFrame()
    
    start_time = datetime.datetime.now()
    a = cleaned_data[0:110].copy()
    a.loc['mean'] = a.mean()
    a.loc['max'] = a.max()
    a.loc['iqr'] = a.quantile(0.75) - a.quantile(0.25)
    a.loc['mad'] = a.mad()
    end_time = datetime.datetime.now()
    time_taken = end_time - start_time
    print("time taken for calculation = ", time_taken)
    
    start_time = datetime.datetime.now()
    mean_data = mean_data.append(a.loc['mean'], ignore_index=True)
    max_data = max_data.append(a.loc['max'], ignore_index=True)
    iqr_data = iqr_data.append(a.loc['iqr'], ignore_index=True)
    mad_data = mad_data.append(a.loc['mad'], ignore_index=True)
        
    end_time = datetime.datetime.now()
    time_taken = end_time - start_time
    print("time taken for appending = ", time_taken)
    start_time = datetime.datetime.now()
    # rearrangement of columns
    mean_data = mean_data.rename(index=str, columns={'AcX 1': 'mean_AcX 1', 'AcY 1': 'mean_AcY 1', 'AcZ 1': 'mean_AcZ 1', 
                                                     'GyX 1': 'mean_GyX 1', 'GyY 1': 'mean_GyY 1', 'GyZ 1': 'mean_GyZ 1',
                                                     'AcX 2': 'mean_AcX 2', 'AcY 2': 'mean_AcY 2', 'AcZ 2': 'mean_AcZ 2', 
                                                     'GyX 2': 'mean_GyX 2', 'GyY 2': 'mean_GyY 2', 'GyZ 2': 'mean_GyZ 2',
                                                     'AcX 3': 'mean_AcX 3', 'AcY 3': 'mean_AcY 3', 'AcZ 3': 'mean_AcZ 3', 
                                                     'GyX 3': 'mean_GyX 3', 'GyY 3': 'mean_GyY 3', 'GyZ 3': 'mean_GyZ 3',})

    max_data = max_data.rename(index=str, columns=  {'AcX 1': 'max_AcX 1', 'AcY 1': 'max_AcY 1', 'AcZ 1': 'max_AcZ 1', 
                                                     'GyX 1': 'max_GyX 1', 'GyY 1': 'max_GyY 1', 'GyZ 1': 'max_GyZ 1',
                                                     'AcX 2': 'max_AcX 2', 'AcY 2': 'max_AcY 2', 'AcZ 2': 'max_AcZ 2', 
                                                     'GyX 2': 'max_GyX 2', 'GyY 2': 'max_GyY 2', 'GyZ 2': 'max_GyZ 2',
                                                     'AcX 3': 'max_AcX 3', 'AcY 3': 'max_AcY 3', 'AcZ 3': 'max_AcZ 3', 
                                                     'GyX 3': 'max_GyX 3', 'GyY 3': 'max_GyY 3', 'GyZ 3': 'max_GyZ 3',})
        
    iqr_data = iqr_data.rename(index=str, columns=  {'AcX 1': 'iqr_AcX 1', 'AcY 1': 'iqr_AcY 1', 'AcZ 1': 'iqr_AcZ 1', 
                                                     'GyX 1': 'iqr_GyX 1', 'GyY 1': 'iqr_GyY 1', 'GyZ 1': 'iqr_GyZ 1',
                                                     'AcX 2': 'iqr_AcX 2', 'AcY 2': 'iqr_AcY 2', 'AcZ 2': 'iqr_AcZ 2', 
                                                     'GyX 2': 'iqr_GyX 2', 'GyY 2': 'iqr_GyY 2', 'GyZ 2': 'iqr_GyZ 2',
                                                     'AcX 3': 'iqr_AcX 3', 'AcY 3': 'iqr_AcY 3', 'AcZ 3': 'iqr_AcZ 3', 
                                                     'GyX 3': 'iqr_GyX 3', 'GyY 3': 'iqr_GyY 3', 'GyZ 3': 'iqr_GyZ 3',}) 
    
    mad_data = mad_data.rename(index=str, columns=  {'AcX 1': 'mad_AcX 1', 'AcY 1': 'mad_AcY 1', 'AcZ 1': 'mad_AcZ 1', 
                                                     'GyX 1': 'mad_GyX 1', 'GyY 1': 'mad_GyY 1', 'GyZ 1': 'mad_GyZ 1',
                                                     'AcX 2': 'mad_AcX 2', 'AcY 2': 'mad_AcY 2', 'AcZ 2': 'mad_AcZ 2', 
                                                     'GyX 2': 'mad_GyX 2', 'GyY 2': 'mad_GyY 2', 'GyZ 2': 'mad_GyZ 2',
                                                     'AcX 3': 'mad_AcX 3', 'AcY 3': 'mad_AcY 3', 'AcZ 3': 'mad_AcZ 3', 
                                                     'GyX 3': 'mad_GyX 3', 'GyY 3': 'mad_GyY 3', 'GyZ 3': 'mad_GyZ 3',})

    end_time = datetime.datetime.now()
    time_taken = end_time - start_time
    print("time taken for renaming = ", time_taken)
    
    # combine features extracted into 1 
    extracted_data = mean_data.join(max_data).join(iqr_data).join(mad_data)

    # store row 110
    data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\test data\%s_dataset.csv' %filename)
    data = data[11::]
    data.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\test data\%s_dataset.csv' %filename ,index=False)
    extracted_data.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\test data\extracted_dataset.csv', index=False)
#     extracted_data.to_csv('/home/pi/3002/ml/extracted_data.csv', index=False)
    start_time = datetime.datetime.now()
    voltage = data['voltage'].iloc[-1]
    current = data['current'].iloc[-1]
    power = data['power'].iloc[-1]
    energy = data['energy'].iloc[-1]
    
    end_time = datetime.datetime.now()
    time_taken = end_time - start_time
    print("time taken for renaming = ", time_taken)
    return [voltage, current, power, energy]

# %%
# data analysis
import pandas as pd

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Evalute the speed of model
import datetime

def predict(mlp_model, rd_model, filename):
    start_time1 = datetime.datetime.now()
    start_time = datetime.datetime.now()
    data_processing(filename)
    end_time = datetime.datetime.now()
    time_taken = end_time - start_time
    print("time taken for data_processing = ", time_taken)
    filename_mlp = "Neural_Network_Model.sav"
    filename_svm = "SVM.sav"
    filename_rd = "RD.sav"
#     data = pd.read_csv('/home/pi/3002/ml/extracted_data.csv')
#     data = pd.read_csv(r'C:\Users\User\Desktop\chicken_extracted_dataset.csv')#
    
#     svm_model = pickle.load(open(filename_svm, 'rb'))
    

    
    start_time = datetime.datetime.now()
    while(True):
        data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\test data\extracted_dataset.csv')
        prediction_mlp = mlp_model.predict(data)
        prediction_rd = rd_model.predict(data)
#         print(prediction_mlp, prediction_rd)

        if (prediction_mlp == prediction_rd):
            break
        data_processing(filename)
    end_time = datetime.datetime.now()
    time_taken = end_time - start_time
    print("time taken for loop = ", time_taken)
    mapping = {0 : 'rest', 1 : 'chicken', 2 : 'number7', 3 : 'sidestep', 4 : 'turnclap', 5 : 'wipers',
               6 : 'numbersix', 7 : 'salute', 8 : 'mermaid', 9 : 'swing', 10 : 'cowboy', 11 : 'finisher'}
    end_time = datetime.datetime.now()
    time_taken = end_time - start_time1
    print("time taken for everything = ", time_taken)
          
    return mapping[prediction_rd[0]]

# %%
# Importation of  model
import pickle
import winsound
a = ['rest', 'chicken', 'number7', 'sidestep', 'turnclap', 'wipers', 'numbersix', 'salute', 'mermaid', 'swing', 'cowboy', 'finisher']
filename_mlp = "Neural_Network_Model.sav"
filename_rd = "RD.sav"
mlp_model = pickle.load(open(filename_mlp, 'rb'))
rd_model = pickle.load(open(filename_rd, 'rb'))

for i in range(50):
    for j in a:
        k = predict(mlp_model, rd_model, j)
        if (k != j):
            print(k, j)
            
print("done")
winsound.Beep(500, 800)

# %%
import pickle

filename_mlp = "Neural_Network_Model.sav"
filename_rd = "RD.sav"
mlp_model = pickle.load(open(filename_mlp, 'rb'))
rd_model = pickle.load(open(filename_rd, 'rb'))
print(predict(mlp_model, rd_model, 'rest'))
print(predict(mlp_model, rd_model, 'chicken'))
print(predict(mlp_model, rd_model, 'number7'))
print(predict(mlp_model, rd_model, 'sidestep'))
print(predict(mlp_model, rd_model, 'turnclap'))
print(predict(mlp_model, rd_model, 'wipers'))
print(predict(mlp_model, rd_model, 'numbersix'))
print(predict(mlp_model, rd_model, 'salute'))
print(predict(mlp_model, rd_model, 'mermaid'))
print(predict(mlp_model, rd_model, 'swing'))
print(predict(mlp_model, rd_model, 'cowboy'))
print(predict(mlp_model, rd_model, 'finisher'))
# Out:
# time taken for reading =  0:00:00.041916
# time taken for calculation =  0:00:00.005986
# time taken for appending =  0:00:00.004956
# time taken for renaming =  0:00:00.001025
# time taken for data_processing =  0:00:00.392950
# time taken for loop =  0:00:00.008006
# time taken for everything =  0:00:00.400956
# rest
# time taken for reading =  0:00:00.247311
# time taken for calculation =  0:00:00.007949
# time taken for appending =  0:00:00.004986
# time taken for renaming =  0:00:00.000997
# time taken for data_processing =  0:00:02.171167
# time taken for loop =  0:00:00.006981
# time taken for everything =  0:00:02.179145
# chicken
# time taken for reading =  0:00:00.225398
# time taken for calculation =  0:00:00.007012
# time taken for appending =  0:00:00.004956
# time taken for renaming =  0:00:00.002006
# time taken for data_processing =  0:00:02.097395
# time taken for loop =  0:00:00.006981
# time taken for everything =  0:00:02.104376
# number7
# time taken for reading =  0:00:00.217420
# time taken for calculation =  0:00:00.005982
# time taken for appending =  0:00:00.004987
# time taken for renaming =  0:00:00.001994
# time taken for data_processing =  0:00:02.107366
# time taken for loop =  0:00:00.006981
# time taken for everything =  0:00:02.114347
# sidestep
# time taken for reading =  0:00:00.192485
# time taken for calculation =  0:00:00.006983
# time taken for appending =  0:00:00.005993
# time taken for renaming =  0:00:00.001018
# time taken for data_processing =  0:00:01.963749
# time taken for loop =  0:00:00.006981
# time taken for everything =  0:00:01.971727
# turnclap
# time taken for reading =  0:00:00.212464
# time taken for calculation =  0:00:00.006003
# time taken for appending =  0:00:00.003990
# time taken for renaming =  0:00:00.000998
# time taken for data_processing =  0:00:02.118339
# time taken for loop =  0:00:00.006981
# time taken for everything =  0:00:02.125320
# wipers
# time taken for reading =  0:00:00.183508
# time taken for calculation =  0:00:00.006984
# time taken for appending =  0:00:00.004987
# time taken for renaming =  0:00:00.001028
# time taken for data_processing =  0:00:01.874987
# time taken for loop =  0:00:00.006981
# time taken for everything =  0:00:01.881968
# numbersix
# time taken for reading =  0:00:00.168549
# time taken for calculation =  0:00:00.006981
# time taken for appending =  0:00:00.004988
# time taken for renaming =  0:00:00.001993
# time taken for data_processing =  0:00:01.536889
# time taken for loop =  0:00:00.007009
# time taken for everything =  0:00:01.543898
# salute
# time taken for reading =  0:00:00.172509
# time taken for calculation =  0:00:00.007977
# time taken for appending =  0:00:00.006981
# time taken for renaming =  0:00:00.001995
# time taken for data_processing =  0:00:02.007632
# time taken for loop =  0:00:00.006948
# time taken for everything =  0:00:02.015581
# mermaid
# time taken for reading =  0:00:00.154585
# time taken for calculation =  0:00:00.006981
# time taken for appending =  0:00:00.003990
# time taken for renaming =  0:00:00.001994
# time taken for data_processing =  0:00:01.536901
# time taken for loop =  0:00:00.006981
# time taken for everything =  0:00:01.545868
# swing
# time taken for reading =  0:00:00.178524
# time taken for calculation =  0:00:00.007979
# time taken for appending =  0:00:00.004988
# time taken for renaming =  0:00:00.001992
# time taken for data_processing =  0:00:01.824123
# time taken for loop =  0:00:00.006980
# time taken for everything =  0:00:01.832103
# cowboy
# time taken for reading =  0:00:00.153589
# time taken for calculation =  0:00:00.005984
# time taken for appending =  0:00:00.004986
# time taken for renaming =  0:00:00.000998
# time taken for data_processing =  0:00:01.445136
# time taken for loop =  0:00:00.006972
# time taken for everything =  0:00:01.454112
# finisher
